# %%
import pandas as pd
import sqlite3
import polygon
import fredapi as Fred
import requests

import time
##########################
import yfinance

from Keys import FMPKey
from Keys import PolygonKey
from Keys import FREDKey

# %% [markdown]
# # Options Client

# %%
class OptionsClient:
    """
    dependencies = [pandas, polygon]
    """
    def __init__(self, api_key):
        self.client = polygon.RESTClient(api_key=api_key)

    def get_list_from_ticker(self, ticker, raw=False):
        contracts = []
        for i in self.client.list_options_contracts(underlying_ticker=ticker.upper(), limit=1000):
            contracts.append(i)
        
        if raw:
            df_raw = pd.DataFrame(contracts)
            return df_raw
        else:
            df = pd.DataFrame(contracts)
            df.drop(columns=[
                'additional_underlyings',
                'cfi',
                'correction',
                'primary_exchange',
                'shares_per_contract',
                'exercise_style',
                'underlying_ticker'
                ], axis=1, inplace=True)
            df.rename({
                'contract_type':'type',
                'ticker':'contract_ticker',
                'underlying_ticker':'stock_ticker'
                }, axis=1, inplace=True)
            df['expiration_date'] = pd.to_datetime(df['expiration_date'])
            df['ticker'] = ticker.upper()
            return df
        
    def get_aggs(self, contract_ticker, raw=False):
        lists = []
        for c in self.client.list_aggs(contract_ticker, 1, 'day', '2000-01-01', '2025-01-01', limit=5000):
            lists.append(c)
        df = pd.DataFrame(lists)
        if df.empty:
            return "no data"
        else:
            df['date'] = df['timestamp'].astype('datetime64[ms]')
            df['date'] = pd.to_datetime(df['date'].dt.date)
            df.drop(['timestamp', 'transactions', 'otc'], axis=1, inplace=True)
            df['contract_ticker'] = contract_ticker
            return df

# %% [markdown]
# # DB interactions

# %%
class DataBaseClient:
    """
    dependencies = [pandas, sqlite3]
    """
    def __init__(self, db_name):
        self.db = db_name
        self.conn = sqlite3.connect(db_name)

    def data_query(self, sql_string):
        df = pd.read_sql(sql_string, self.conn)
        if 'date' in df.columns:
            df['date'] = pd.to_datetime(df['date'])
            return df
        elif 'expiration_date' in df.columns:
            df['expiration_date'] = pd.to_datetime(df['expiration_date'])
            return df
        else:
            return df
        
    def data_add(self, df, table_name):
        df.to_sql(table_name, self.conn, if_exists='append', index=False)

    def get_table_names(self):
        df = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", self.conn)
        return df 
    
    def close_db(self):
        self.conn.close()

    def delete_table(self, table_name):
        self.conn.execute(f"DROP TABLE {table_name}")

# %% [markdown]
# # Fred Client

# %%
class FredClient:
    def __init__(self, api_key):
        self.fred = Fred(api_key=api_key)

    def fred_data_clean_(self, data):
        df = pd.DataFrame(data, columns=['value'])
        df.reset_index(inplace=True)
        df.rename(columns={'index': 'date'}, inplace=True)
        df['date'] = pd.to_datetime(df['date'])
        return df

    def get_series(self, series, raw=False):
        data = self.fred.get_series(series)
        if raw:
            return data
        df = self.fred_data_clean_(data)
        return df
    
    def get_fed_funds_rate(self, raw=False):
        if raw is True:
            df_full = self.get_series('DFF', raw=raw)
            return df
        else:
            df = self.get_series('DFF', raw=raw)
            df = df[df['date'].dt.year >= 2000]
            df.reset_index(drop=True, inplace=True)
            return df

# %% [markdown]
# # Yahoo Finance

# %%
class YahooIndexClient:
    def __init__(self):
        pass

    def get_index(self, ticker, raw=False):
        ticker_object = yfinance.Ticker(ticker.upper())
        df = ticker_object.history(period='max')
        df.reset_index(inplace=True)
        df.drop(columns=['Dividends', 'Stock Splits', 'Volume'], axis=1, inplace=True)
        df['Date'] = pd.to_datetime(df['Date'])
        df['Date'] = pd.to_datetime(df['Date'].dt.date)
        df.rename(columns={
            'Date':'date',
            'Open':'open',
            'High':'high',
            'Low':'low',
            'Close':'close'
            }, inplace=True)
        df = df[df['date'].dt.year >= 2000]
        return df

# %% [markdown]
# # Old Finpy

# %%
def binary_up_down_(ovnChange):
    if ovnChange >= 0:
        return 1
    else:
        return 0

def data_shifts_(df):
    df['futureClose'] = df['close'].shift(1)
    df['ovnChange'] = df['open'] - df['close'].shift(-1)
    df['ovnChangePercent'] = (df['ovnChange'] / df['close'].shift(-1)) * 100
    df['futureCloseBin'] = df['futureClose'].apply(binary_up_down_)
    df.at[0, 'futureCloseBin'] = np.nan
    return df


class API:
    api_key = None

    def set_api_key(self, input_key: str):
        API.api_key = input_key
    def __init__(self):
        self.base_url = 'https://financialmodelingprep.com/api/v3/'
        self.api_key = API.api_key


class Search(API):
    def __init__(self, ticker: str):
        super().__init__()
        self.ticker = ticker.upper()

    def price(self, date_range=None, raw=False):
        if date_range is None:
            url = f'{self.base_url}historical-price-full/{self.ticker}?from=2000-01-01&to=2025-01-01&apikey={self.api_key}'
            r = requests.get(url)
            if r.status_code == 200:
                data = r.json()
                if not data:
                    return "ERROR! dictionary empty; check parameters"
                else:
                    if raw is False:
                        data = r.json()['historical']
                        df = pd.DataFrame(data)
                        df.drop(['adjClose', 'unadjustedVolume', 'vwap', 'label', 'changeOverTime'], axis=1, inplace=True)
                        df = data_shifts_(df)
                        return df
                    elif raw is True:
                        return data
                    else:
                        return "ERROR! raw parameter can only be boolian True of False"
            else:
                    return r.json()
            
        elif isinstance(date_range, list):
            check_dates = {}
            for date in date_range:
                if re.match(r"^(19\d{2}|20[0-2]\d)-(0[1-9]|1[0-2])-(0[1-9]|[12]\d|3[01])$", date):
                    check_dates[True] = date
                else:
                    check_dates[False] = date
            if False in check_dates:
                return "ERROR! date's are not properly formated in YYYY-MM-DD"
            else:
                url = f'{self.base_url}historical-price-full/{self.ticker}?from={date_range[0]}&to={date_range[1]}&apikey={self.api_key}'
                r = requests.get(url)
                if r.status_code == 200:
                    data = r.json()
                    if not data:
                        return "ERROR! dictionary empty; check parameters"
                    else:
                        if raw is False:
                            data = r.json()['historical']
                            df = pd.DataFrame(data)
                            df.drop(['adjClose', 'unadjustedVolume', 'vwap', 'label', 'changeOverTime'], axis=1, inplace=True)
                            df = data_shifts_(df)
                            return df
                        elif raw is True:
                            return data
                        else:
                            return "ERROR! raw parameter can only be boolian True of False"
                else:
                        return r.json()
                
        else:
            return "date_range must be a list of dates ['start', 'end'] and date must be in YYYY-MM-DD format"
        

class Lists(API):
    def __init__(self):
        super().__init__()
        url_screener = f'https://financialmodelingprep.com/api/v3/stock/list?apikey={self.api_key}'
        r_screener = requests.get(url_screener)
        df_screener = pd.DataFrame(r_screener.json())
        self.screener_all_ = df_screener

        url_industry = f'https://financialmodelingprep.com/api/v3/industries-list?apikey={self.api_key}'
        r_industry = requests.get(url_industry)
        df_industry = pd.DataFrame(r_industry.json())
        df_industry.rename(columns={0:'industry'}, inplace=True)
        self.industry_ = df_industry

        url_sector = f'https://financialmodelingprep.com/api/v3/sectors-list?apikey={self.api_key}'
        r_sector = requests.get(url_sector)
        df_sector = pd.DataFrame(r_sector.json())
        df_sector.rename(columns={0:'sector'}, inplace=True)
        self.sector_ = df_sector
    
    us_exchanges = [
    'NASDAQ',
    'OTC',
    'NYSE',
    'AMEX',
    'CBOE',
    ]

    def etfs(self):
        df = self.all_[self.all_['type'] == 'etf']
        df = df.reset_index(drop=True)
        return df
    
    def trusts(self):
        df = self.all_[self.all_['type'] == 'trust']
        df = df.reset_index(drop=True)
        return df

    def funds(self):
        df = self.all_[self.all_['type'] == 'fund']
        df = df.reset_index(drop=True)
        return df

    def stocks(self):
        df = self.all_[self.all_['type'] == 'stock']
        df = df.reset_index(drop=True)
        return df

    def us_etfs(self):
        df = self.all_[self.all_['type'] == 'etf']
        df = df[df['exchangeShortName'].isin(self.us_exchanges)]
        df = df.reset_index(drop=True)
        return df
    
    def us_trusts(self):
        df = self.all_[self.all_['type'] == 'trust']
        df = df[df['exchangeShortName'].isin(self.us_exchanges)]
        df = df.reset_index(drop=True)
        return df
    
    def us_funds(self):
        df = self.all_[self.all_['type'] == 'fund']
        df = df[df['exchangeShortName'].isin(self.us_exchanges)]
        df = df.reset_index(drop=True)
        return df
    
    def us_stocks(self):
        df = self.all_[self.all_['type'] == 'stock']
        df = df[df['exchangeShortName'].isin(self.us_exchanges)]
        df = df.reset_index(drop=True)
        return df
    
    def industries(self):
        url = f'https://financialmodelingprep.com/api/v3/industries-list?apikey={self.api_key}'
        r = requests.get(url)
        df = pd.DataFrame(r.json())
        df.rename(columns={0:'industry'}, inplace=True)
        return df
    
    def sectors(self):
        url = f'https://financialmodelingprep.com/api/v3/sectors-list?apikey={self.api_key}'
        r = requests.get(url)
        df = pd.DataFrame(r.json())
        df.rename(columns={0:'sector'}, inplace=True)
        return df
    

    def get_cash_flow(self):
        url = f'{self.base_url}cash-flow-statement/AAPL?period=annual&apikey={self.api_key}'
        data = self.request_(url)
        return data

# %% [markdown]
# # New FMP Attempt

# %%
############################
class ToGoThrough:
    def sector_industry_data_clean_(self, data):
        df = pd.DataFrame(data)
        df = df[['symbol', 'companyName', 'exchangeShortName']]
        df.rename(columns={
            'companyName':'name',
            'exchangeShortName':'exchange'
        }, inplace=True)
        df = df[df['exchange'].isin(['NASDAQ', 'NYSE'])]
        df.reset_index(inplace=True, drop=True)
        df = df[['symbol', 'name']]
        return df

    def get_sectors(self):
        url = f'{self.base_url}sectors-list?apikey={self.api_key}'
        data = self.request_(url)
        data_sorted = sorted(data)
        return sorted(data)

    def get_industries(self):
        url = f'{self.base_url}industries-list?apikey={self.api_key}'
        data = self.request_(url)
        data_sorted = sorted(data)
        return data_sorted

    def sector_search(self, sector, simple=True):
        url = f'{self.base_url}stock-screener?apikey={self.api_key}&isEtf=false&isFund=false&isActivelyTrading=true&sector={sector}'
        data = self.request_(url)
        data_clean = self.sector_industry_data_clean_(data)
        return data_clean

    def industry_search(self, industry):
        url = f'{self.base_url}stock-screener?apikey={self.api_key}&isEtf=false&isFund=false&isActivelyTrading=true&industry={industry}'
        data = self.request_(url)
        data_clean = self.sector_industry_data_clean_(data)
        return data_clean



    #################################

    def income_statement_data_clean_(self, data):
        df = pd.DataFrame(data)
        df.rename(columns={
            'calendarYear':'year',
            'costOfRevenue':'cost_of_revenue',
            'grossProfit':'gross_profit',
            'grossProfitRatio':'gross_profit_ratio',
            'researchAndDevelopmentExpenses':'r_and_d_exp',
            'generalAndAdministrativeExpenses':'general_and_admin_exp',
            'sellingAndMarketingExpenses':'selling_and_marketing_exp',
            'sellingGeneralAndAdministrativeExpenses':'selling_general_and_admin_exp',
            'otherExpenses':'other_exp',
            'operatingExpenses':'operating_exp',
            'costAndExpenses':'cost_and_exp',
            'interestIncome':'interest_income',
            'interestExpense':'interest_expense',
            'depreciationAndAmortization': 'depreciation_and_amortization',
            'ebitdaratio':'ebitda_ratio',
            'operatingIncome':'operating_income',
            'operatingIncomeRatio':'operating_income_ratio',
            'totalOtherIncomeExpensesNet':'total_other_income_exp_net',
            'incomeBeforeTax':'income_before_tax',
            'incomeBeforeTaxRatio':'income_before_tax_ratio',
            'incomeTaxExpense':'income_tax_expense',
            'netIncome':'net_income',
            'netIncomeRatio':'net_income_ratio',
        }, inplace=True)

        df.drop(columns=[
            'reportedCurrency',
            'cik',
            'link',
            'date',
            'finalLink',
            'acceptedDate',
            'epsdiluted',
            'weightedAverageShsOut',
            'weightedAverageShsOutDil'
        ],inplace=True)
        df['date'] = pd.to_datetime(df['fillingDate'])
        df.drop(columns=['fillingDate'], inplace=True)
        df = df[df['date'].dt.year >= 2000]
        return df

    def get_income_statement_q(self, ticker):
        url = f'{self.base_url}income-statement/{ticker.upper()}?period=quarter&apikey={self.api_key}'
        data = self.request_(url)
        df = self.income_statement_data_clean_(data)
        return df

    def get_income_statement_a(self, ticker):
        url = f'{self.base_url}income-statement/{ticker.upper()}?period=quarter&apikey={self.api_key}'
        data = self.request_(url)
        return data
    
    #################################
    
    def income_statement_data_clean_(self, data):
        df = pd.DataFrame(data)
        df.rename(columns={
            'calendarYear':'year',
            'costOfRevenue':'cost_of_revenue',
            'grossProfit':'gross_profit',
            'grossProfitRatio':'gross_profit_ratio',
            'researchAndDevelopmentExpenses':'r_and_d_exp',
            'generalAndAdministrativeExpenses':'general_and_admin_exp',
            'sellingAndMarketingExpenses':'selling_and_marketing_exp',
            'sellingGeneralAndAdministrativeExpenses':'selling_general_and_admin_exp',
            'otherExpenses':'other_exp',
            'operatingExpenses':'operating_exp',
            'costAndExpenses':'cost_and_exp',
            'interestIncome':'interest_income',
            'interestExpense':'interest_expense',
            'depreciationAndAmortization': 'depreciation_and_amortization',
            'ebitdaratio':'ebitda_ratio',
            'operatingIncome':'operating_income',
            'operatingIncomeRatio':'operating_income_ratio',
            'totalOtherIncomeExpensesNet':'total_other_income_exp_net',
            'incomeBeforeTax':'income_before_tax',
            'incomeBeforeTaxRatio':'income_before_tax_ratio',
            'incomeTaxExpense':'income_tax_expense',
            'netIncome':'net_income',
            'netIncomeRatio':'net_income_ratio',
        }, inplace=True)

        df.drop(columns=[
            'reportedCurrency',
            'cik',
            'link',
            'date',
            'finalLink',
            'acceptedDate',
            'epsdiluted',
            'weightedAverageShsOut',
            'weightedAverageShsOutDil'
        ],inplace=True)
        df['date'] = pd.to_datetime(df['fillingDate'])
        df.drop(columns=['fillingDate'], inplace=True)
        df = df[df['date'].dt.year >= 2000]
        return df
    
    def get_balance_sheet(self):
        url = f'{self.base_url}balance-sheet-statement/AAPL?period=annual&apikey={self.api_key}'
        data = self.request_(url)
        return data

# %%
class FmpClient:
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_url = 'https://financialmodelingprep.com/api/v3/'
        self.utils = self.Utils()

    class Utils:
        def __init__(self):
            pass
        
        def request_(self, url):
            r = requests.get(url)
            if r.status_code == 200:
                data = r.json()
                if not data:
                    return "ERROR! dictionary empty; check request parameters"
                else:
                    return data
            else:
                return r.json()

        def aggs_data_clean_(self, raw_data):
            data = raw_data['historical']
            df = pd.DataFrame(data)
            df.drop(columns=[
                'unadjustedVolume',
                'label',
                'changeOverTime',
                'adjClose'
            ], axis=1, inplace=True)
            df.rename(columns={
                'changePercent':'percent_change'
            }, inplace=True)
            df['date'] = pd.to_datetime(df['date'])
            df['change'] = round(df['change'], 4)
            df['percent_change'] = round(df['percent_change'], 4)
            df['vwap'] = round(df['vwap'], 4)
            return df

        def human_num_read_(self, number):
            suffixes = ['', 'K', 'M', 'B', 'T']
            magnitude = 0
            num = float(number)
            while abs(num) >= 1000 and magnitude < len(suffixes) - 1:
                magnitude += 1
                num /= 1000.0
            human_readable = f"{num:.3}{suffixes[magnitude]}"
            return human_readable
        
        def sector_industry_data_clean_(self, data):
            df = pd.DataFrame(data)
            df = df[['symbol', 'companyName', 'exchangeShortName']]
            df.rename(columns={
                'companyName':'name',
                'exchangeShortName':'exchange'
            }, inplace=True)
            df = df[df['exchange'].isin(['NASDAQ', 'NYSE'])]
            df.reset_index(inplace=True, drop=True)
            df = df[['symbol', 'name']]
            return df
        
        def income_statement_data_clean_(self, data):
            df = pd.DataFrame(data)
            df.rename(columns={
                'calendarYear':'year',
                'costOfRevenue':'cost_of_revenue',
                'grossProfit':'gross_profit',
                'grossProfitRatio':'gross_profit_ratio',
                'researchAndDevelopmentExpenses':'r_and_d_exp',
                'generalAndAdministrativeExpenses':'general_and_admin_exp',
                'sellingAndMarketingExpenses':'selling_and_marketing_exp',
                'sellingGeneralAndAdministrativeExpenses':'selling_general_and_admin_exp',
                'otherExpenses':'other_exp',
                'operatingExpenses':'operating_exp',
                'costAndExpenses':'cost_and_exp',
                'interestIncome':'interest_income',
                'interestExpense':'interest_expense',
                'depreciationAndAmortization': 'depreciation_and_amortization',
                'ebitdaratio':'ebitda_ratio',
                'operatingIncome':'operating_income',
                'operatingIncomeRatio':'operating_income_ratio',
                'totalOtherIncomeExpensesNet':'total_other_income_exp_net',
                'incomeBeforeTax':'income_before_tax',
                'incomeBeforeTaxRatio':'income_before_tax_ratio',
                'incomeTaxExpense':'income_tax_expense',
                'netIncome':'net_income',
                'netIncomeRatio':'net_income_ratio',
            }, inplace=True)
            df.drop(columns=[
                'reportedCurrency',
                'cik',
                'link',
                'date',
                'finalLink',
                'acceptedDate',
                'epsdiluted',
                'weightedAverageShsOut',
                'weightedAverageShsOutDil'
            ],inplace=True)
            df['date'] = pd.to_datetime(df['fillingDate'])
            df.drop(columns=['fillingDate'], inplace=True)
            df = df[df['date'].dt.year >= 2000]
            return df

    ##############################
    ##############################
    ##############################

    def get_aggs(self, ticker):
        url = f'{self.base_url}historical-price-full/{ticker.upper()}?from=2000-01-01&to=2025-01-01&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = self.utils.aggs_data_clean_(data)
            df['ticker'] = ticker.upper()
            return df

    def get_price_rt(self, ticker):
        url = f'{self.base_url}quote-short/{ticker.upper()}?apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            return df

    def get_market_cap_rt(self, ticker, human=False):
        url = f'{self.base_url}market-capitalization/{ticker.upper()}?from=2000-01-01&to-2025-01-01&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            df.drop(columns=['date'], inplace=True)
            df.rename(columns={'marketCap':'market_cap'}, inplace=True)
            if human:
                df['market_cap'] = df['market_cap'].apply(self.human_read_)
                return df
            else:
                return df

    def get_market_cap_range(self, ticker, start, finish):
        url = f'{self.base_url}historical-market-capitalization/{ticker.upper()}?&from={start}&to={finish}&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            df.rename(columns={'marketCap':'market_cap'}, inplace=True)
            df['date'] = pd.to_datetime(df['date'])
            return df

    def get_market_cap_history(self, ticker):
        dates = [
            ['2000-01-01','2005-01-01'],
            ['2005-01-01', '2010-01-01'],
            ['2010-01-01', '2015-01-01'],
            ['2015-01-01', '2020-01-01'],
            ['2020-01-01', '2025-01-01']
        ]
        df = pd.DataFrame()
        for i in dates:
            data = self.get_market_cap_range(ticker.upper(), i[0], i[1])
            if isinstance(data, str) and data == "ERROR! dictionary empty; check request parameters":
                continue
            else:
                df = pd.concat([df, data], ignore_index=True)
        if df.empty:
            return "ERROR! DataFrame empty; check request parameters"
        df = df.sort_values(by='date').reset_index(drop=True)
        return df
    
    ###########################

    def get_snp_companies(self):
        url = f'{self.base_url}sp500_constituent?apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            df.drop(columns='cik', inplace=True)
            df.rename(columns={
                'subSector':'sub_sector',
                'headQuarter': 'hq',
                'dateFirstAdded': 'date_added'
            }, inplace=True)
            return df

    def get_dow_companies(self):
        url = f'{self.base_url}dowjones_constituent?apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            df.drop(columns='cik', inplace=True)
            df.rename(columns={
                'subSector':'sub_sector',
                'headQuarter': 'hq',
                'dateFirstAdded': 'date_added'
            }, inplace=True)
            return df
        
    def get_nasdaq_companies(self):
        url = f'{self.base_url}nasdaq_constituent?apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = pd.DataFrame(data)
            df.drop(columns='cik', inplace=True)
            df.rename(columns={
                'subSector':'sub_sector',
                'headQuarter': 'hq',
                'dateFirstAdded': 'date_added'
            }, inplace=True)
            return df  

    ####################################

    def get_income_statement_q(self, ticker):
        url = f'{self.base_url}income-statement/{ticker.upper()}?period=quarter&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = self.utils.income_statement_data_clean_(data)
            return df

    def get_income_statement_a(self, ticker):
        url = f'{self.base_url}income-statement/{ticker.upper()}?period=annual&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            df = self.utils.income_statement_data_clean_(data)
            return df  
    
    def get_balance_sheet_a(self, ticker):
        url = f'{self.base_url}balance-sheet-statement/{ticker.upper()}?period=annual&apikey={self.api_key}'
        data = self.utils.request_(url)
        if data == "ERROR! dictionary empty; check request parameters":
            return "ERROR! dictionary empty; check initial request"
        else:
            return data

# %%
fmp = FmpClient(FMPKey)
df = fmp.get_balance_sheet_a('jpm')
df
# Out:
# [{'date': '2023-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2024-02-16',
#   'acceptedDate': '2024-02-16 16:20:22',
#   'calendarYear': '2023',
#   'period': 'FY',
#   'cashAndCashEquivalents': 624151000000,
#   'shortTermInvestments': 192485000000,
#   'cashAndShortTermInvestments': 305218000000,
#   'netReceivables': 107363000000,
#   'inventory': -1856346000000,
#   'otherCurrentAssets': 1748983000000,
#   'totalCurrentAssets': 305218000000,
#   'propertyPlantEquipmentNet': 30157000000,
#   'goodwill': 52634000000,
#   'intangibleAssets': 11747000000,
#   'goodwillAndIntangibleAssets': 64381000000,
#   'longTermInvestments': 973946000000,
#   'taxAssets': -879408000000,
#   'otherNonCurrentAssets': -94538000000,
#   'totalNonCurrentAssets': 94538000000,
#   'otherAssets': 3475637000000,
#   'totalAssets': 3875393000000,
#   'accountPayables': 161960000000,
#   'shortTermDebt': 44712000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -161960000000,
#   'totalCurrentLiabilities': 44712000000,
#   'longTermDebt': 391825000000,
#   'deferredRevenueNonCurrent': -7762000000,
#   'deferredTaxLiabilitiesNonCurrent': 7762000000,
#   'otherNonCurrentLiabilities': 23020000000,
#   'totalNonCurrentLiabilities': 414845000000,
#   'otherLiabilities': 3087958000000,
#   'capitalLeaseObligations': 6746000000,
#   'totalLiabilities': 3547515000000,
#   'preferredStock': 27404000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 332901000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -10443000000,
#   'othertotalStockholdersEquity': -26089000000,
#   'totalStockholdersEquity': 327878000000,
#   'totalEquity': 327878000000,
#   'totalLiabilitiesAndStockholdersEquity': 3875393000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 3875393000000,
#   'totalInvestments': 201704000000,
#   'totalDebt': 436537000000,
#   'netDebt': -187614000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961724000225/0000019617-24-000225-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961724000225/jpm-20231231.htm'},
#  {'date': '2022-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2023-02-21',
#   'acceptedDate': '2023-02-21 16:13:55',
#   'calendarYear': '2022',
#   'period': 'FY',
#   'cashAndCashEquivalents': 567234000000,
#   'shortTermInvestments': 205857000000,
#   'cashAndShortTermInvestments': 773091000000,
#   'netReceivables': 196069000000,
#   'inventory': -1647386000000,
#   'otherCurrentAssets': 1647386000000,
#   'totalCurrentAssets': 969160000000,
#   'propertyPlantEquipmentNet': 27734000000,
#   'goodwill': 51662000000,
#   'intangibleAssets': 9197000000,
#   'goodwillAndIntangibleAssets': 60859000000,
#   'longTermInvestments': 1014081000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -1102674000000,
#   'totalNonCurrentAssets': 1102674000000,
#   'otherAssets': 1593909000000,
#   'totalAssets': 3665743000000,
#   'accountPayables': 300141000000,
#   'shortTermDebt': 44027000000,
#   'taxPayables': 46166000000,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -344168000000,
#   'totalCurrentLiabilities': 344168000000,
#   'longTermDebt': 422700000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 2908821000000,
#   'totalNonCurrentLiabilities': 3331521000000,
#   'otherLiabilities': -302278000000,
#   'capitalLeaseObligations': 6611000000,
#   'totalLiabilities': 3373411000000,
#   'preferredStock': 27404000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 296456000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -17341000000,
#   'othertotalStockholdersEquity': -18292000000,
#   'totalStockholdersEquity': 292332000000,
#   'totalEquity': 292332000000,
#   'totalLiabilitiesAndStockholdersEquity': 3665743000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 3665743000000,
#   'totalInvestments': 1219938000000,
#   'totalDebt': 466727000000,
#   'netDebt': -100507000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/0000019617-23-000231-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961723000231/jpm-20221231.htm'},
#  {'date': '2021-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2022-02-22',
#   'acceptedDate': '2022-02-22 16:56:31',
#   'calendarYear': '2021',
#   'period': 'FY',
#   'cashAndCashEquivalents': 740834000000,
#   'shortTermInvestments': 308525000000,
#   'cashAndShortTermInvestments': 1049359000000,
#   'netReceivables': 159651000000,
#   'inventory': -1744961000000,
#   'otherCurrentAssets': 1744961000000,
#   'totalCurrentAssets': 1209010000000,
#   'propertyPlantEquipmentNet': 27070000000,
#   'goodwill': 50315000000,
#   'intangibleAssets': 6376000000,
#   'goodwillAndIntangibleAssets': 56691000000,
#   'longTermInvestments': 1048726000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -1132487000000,
#   'totalNonCurrentAssets': 1132487000000,
#   'otherAssets': 1402070000000,
#   'totalAssets': 3743567000000,
#   'accountPayables': 262755000000,
#   'shortTermDebt': 53594000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -316349000000,
#   'totalCurrentLiabilities': 316349000000,
#   'longTermDebt': 415582000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -415582000000,
#   'totalNonCurrentLiabilities': 415582000000,
#   'otherLiabilities': 2717509000000,
#   'capitalLeaseObligations': 6756000000,
#   'totalLiabilities': 3449440000000,
#   'preferredStock': 34838000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 272268000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -84000000,
#   'othertotalStockholdersEquity': -17000000000,
#   'totalStockholdersEquity': 294127000000,
#   'totalEquity': 294127000000,
#   'totalLiabilitiesAndStockholdersEquity': 3743567000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 3743567000000,
#   'totalInvestments': 1357251000000,
#   'totalDebt': 469176000000,
#   'netDebt': -271658000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961722000272/0000019617-22-000272-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961722000272/jpm-20211231.htm'},
#  {'date': '2020-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2021-02-23',
#   'acceptedDate': '2021-02-23 16:17:29',
#   'calendarYear': '2020',
#   'period': 'FY',
#   'cashAndCashEquivalents': 527609000000,
#   'shortTermInvestments': 388178000000,
#   'cashAndShortTermInvestments': 915787000000,
#   'netReceivables': 170133000000,
#   'inventory': -1578413000000,
#   'otherCurrentAssets': 1578413000000,
#   'totalCurrentAssets': 1085920000000,
#   'propertyPlantEquipmentNet': 27109000000,
#   'goodwill': 49248000000,
#   'intangibleAssets': 4180000000,
#   'goodwillAndIntangibleAssets': 53428000000,
#   'longTermInvestments': 1013495000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -1094032000000,
#   'totalNonCurrentAssets': 1094032000000,
#   'otherAssets': 1206119000000,
#   'totalAssets': 3386071000000,
#   'accountPayables': 232599000000,
#   'shortTermDebt': 45208000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -277807000000,
#   'totalCurrentLiabilities': 277807000000,
#   'longTermDebt': 381243000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -381243000000,
#   'totalNonCurrentLiabilities': 381243000000,
#   'otherLiabilities': 2447667000000,
#   'capitalLeaseObligations': 8508000000,
#   'totalLiabilities': 3106717000000,
#   'preferredStock': 30063000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 236990000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 7986000000,
#   'othertotalStockholdersEquity': 210000000,
#   'totalStockholdersEquity': 279354000000,
#   'totalEquity': 279354000000,
#   'totalLiabilitiesAndStockholdersEquity': 3386071000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 3386071000000,
#   'totalInvestments': 1401673000000,
#   'totalDebt': 426451000000,
#   'netDebt': -101158000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961721000236/0000019617-21-000236-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961721000236/jpm-20201231.htm'},
#  {'date': '2019-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2020-02-25',
#   'acceptedDate': '2020-02-25 16:31:02',
#   'calendarYear': '2019',
#   'period': 'FY',
#   'cashAndCashEquivalents': 263631000000,
#   'shortTermInvestments': 361337000000,
#   'cashAndShortTermInvestments': 624968000000,
#   'netReceivables': 122627000000,
#   'inventory': -1136854000000,
#   'otherCurrentAssets': 1136854000000,
#   'totalCurrentAssets': 747595000000,
#   'propertyPlantEquipmentNet': 25813000000,
#   'goodwill': 47823000000,
#   'intangibleAssets': 5518000000,
#   'goodwillAndIntangibleAssets': 53341000000,
#   'longTermInvestments': 759576000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -838730000000,
#   'totalNonCurrentAssets': 838730000000,
#   'otherAssets': 1101054000000,
#   'totalAssets': 2687379000000,
#   'accountPayables': 210407000000,
#   'shortTermDebt': 40920000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -251327000000,
#   'totalCurrentLiabilities': 251327000000,
#   'longTermDebt': 367067000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -367067000000,
#   'totalNonCurrentLiabilities': 367067000000,
#   'otherLiabilities': 1807655000000,
#   'capitalLeaseObligations': 6901000000,
#   'totalLiabilities': 2426049000000,
#   'preferredStock': 26993000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 223211000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 1569000000,
#   'othertotalStockholdersEquity': 5452000000,
#   'totalStockholdersEquity': 261330000000,
#   'totalEquity': 261330000000,
#   'totalLiabilitiesAndStockholdersEquity': 2687379000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2687379000000,
#   'totalInvestments': 1120913000000,
#   'totalDebt': 407987000000,
#   'netDebt': 144356000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961720000257/0000019617-20-000257-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961720000257/corp10k2019.htm'},
#  {'date': '2018-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2019-02-26',
#   'acceptedDate': '2019-02-26 16:57:25',
#   'calendarYear': '2018',
#   'period': 'FY',
#   'cashAndCashEquivalents': 278793000000,
#   'shortTermInvestments': 359501000000,
#   'cashAndShortTermInvestments': 509187000000,
#   'netReceivables': 127413000000,
#   'inventory': -1253772000000,
#   'otherCurrentAssets': 1199559000000,
#   'totalCurrentAssets': 582387000000,
#   'propertyPlantEquipmentNet': 14934000000,
#   'goodwill': 47471000000,
#   'intangibleAssets': 6878000000,
#   'goodwillAndIntangibleAssets': 54349000000,
#   'longTermInvestments': 621329000000,
#   'taxAssets': 620892000000,
#   'otherNonCurrentAssets': -655752000000,
#   'totalNonCurrentAssets': 655752000000,
#   'otherAssets': 1384393000000,
#   'totalAssets': 2622532000000,
#   'accountPayables': 196710000000,
#   'shortTermDebt': 69276000000,
#   'taxPayables': 0,
#   'deferredRevenue': 102154000000,
#   'otherCurrentLiabilities': -184070000000,
#   'totalCurrentLiabilities': 184070000000,
#   'longTermDebt': 385035000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -103004000000,
#   'totalNonCurrentLiabilities': 282031000000,
#   'otherLiabilities': 1899916000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2366017000000,
#   'preferredStock': 26068000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 199202000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -1507000000,
#   'othertotalStockholdersEquity': 28647000000,
#   'totalStockholdersEquity': 256515000000,
#   'totalEquity': 256515000000,
#   'totalLiabilitiesAndStockholdersEquity': 2622532000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2622532000000,
#   'totalInvestments': 816863000000,
#   'totalDebt': 454311000000,
#   'netDebt': 175518000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961719000054/0000019617-19-000054-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961719000054/corp10k2018.htm'},
#  {'date': '2017-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2018-02-27',
#   'acceptedDate': '2018-02-27 16:23:03',
#   'calendarYear': '2017',
#   'period': 'FY',
#   'cashAndCashEquivalents': 430121000000,
#   'shortTermInvestments': 325321000000,
#   'cashAndShortTermInvestments': 632346000000,
#   'netReceivables': 124252000000,
#   'inventory': -1847718000000,
#   'otherCurrentAssets': 1184676000000,
#   'totalCurrentAssets': 93556000000,
#   'propertyPlantEquipmentNet': 14159000000,
#   'goodwill': 47507000000,
#   'intangibleAssets': 6885000000,
#   'goodwillAndIntangibleAssets': 54392000000,
#   'longTermInvestments': 575279000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -575279000000,
#   'totalNonCurrentAssets': 68551000000,
#   'otherAssets': 2371493000000,
#   'totalAssets': 2533600000000,
#   'accountPayables': 189383000000,
#   'shortTermDebt': 51802000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -189383000000,
#   'totalCurrentLiabilities': 51802000000,
#   'longTermDebt': 369966000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1856139000000,
#   'totalNonCurrentLiabilities': 2226105000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2277907000000,
#   'preferredStock': 26068000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 177676000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -119000000,
#   'othertotalStockholdersEquity': 47963000000,
#   'totalStockholdersEquity': 255693000000,
#   'totalEquity': 255693000000,
#   'totalLiabilitiesAndStockholdersEquity': 2533600000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2533600000000,
#   'totalInvestments': 723966000000,
#   'totalDebt': 421768000000,
#   'netDebt': -8353000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961718000057/0000019617-18-000057-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961718000057/corp10k2017.htm'},
#  {'date': '2016-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2017-02-28',
#   'acceptedDate': '2017-02-28 16:23:41',
#   'calendarYear': '2016',
#   'period': 'FY',
#   'cashAndCashEquivalents': 389635000000,
#   'shortTermInvestments': 308052000000,
#   'cashAndShortTermInvestments': 628526000000,
#   'netReceivables': 116408000000,
#   'inventory': -1809551000000,
#   'otherCurrentAssets': 1140820000000,
#   'totalCurrentAssets': 76203000000,
#   'propertyPlantEquipmentNet': 14131000000,
#   'goodwill': 47288000000,
#   'intangibleAssets': 6958000000,
#   'goodwillAndIntangibleAssets': 54246000000,
#   'longTermInvestments': 597111000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -603207000000,
#   'totalNonCurrentAssets': 62281000000,
#   'otherAssets': 2352488000000,
#   'totalAssets': 2490972000000,
#   'accountPayables': 190543000000,
#   'shortTermDebt': 11738000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -190543000000,
#   'totalCurrentLiabilities': 11738000000,
#   'longTermDebt': 405378000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1819666000000,
#   'totalNonCurrentLiabilities': 2225044000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2236782000000,
#   'preferredStock': 26068000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 162440000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -1175000000,
#   'othertotalStockholdersEquity': 62752000000,
#   'totalStockholdersEquity': 254190000000,
#   'totalEquity': 254190000000,
#   'totalLiabilitiesAndStockholdersEquity': 2490972000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2490972000000,
#   'totalInvestments': 785907000000,
#   'totalDebt': 417116000000,
#   'netDebt': 27481000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961717000314/0000019617-17-000314-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961717000314/corp10k2016.htm'},
#  {'date': '2015-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2016-02-23',
#   'acceptedDate': '2016-02-23 16:17:46',
#   'calendarYear': '2015',
#   'period': 'FY',
#   'cashAndCashEquivalents': 360505000000,
#   'shortTermInvestments': 284162000000,
#   'cashAndShortTermInvestments': 602259000000,
#   'netReceivables': 106282000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 67095000000,
#   'propertyPlantEquipmentNet': 14362000000,
#   'goodwill': 47325000000,
#   'intangibleAssets': 7623000000,
#   'goodwillAndIntangibleAssets': 54948000000,
#   'longTermInvestments': 574989000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -581597000000,
#   'totalNonCurrentAssets': 62702000000,
#   'otherAssets': 2221901000000,
#   'totalAssets': 2351698000000,
#   'accountPayables': 177638000000,
#   'shortTermDebt': 15562000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -177638000000,
#   'totalCurrentLiabilities': 15562000000,
#   'longTermDebt': 383863000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1704700000000,
#   'totalNonCurrentLiabilities': 2088563000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2104125000000,
#   'preferredStock': 26068000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 146420000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 192000000,
#   'othertotalStockholdersEquity': 70788000000,
#   'totalStockholdersEquity': 247573000000,
#   'totalEquity': 247573000000,
#   'totalLiabilitiesAndStockholdersEquity': 2351698000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2351698000000,
#   'totalInvestments': 762996000000,
#   'totalDebt': 399425000000,
#   'netDebt': 38920000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961716000902/0000019617-16-000902-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961716000902/corp10k2015.htm'},
#  {'date': '2014-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2015-02-24',
#   'acceptedDate': '2015-02-24 16:04:18',
#   'calendarYear': '2014',
#   'period': 'FY',
#   'cashAndCashEquivalents': 512308000000,
#   'shortTermInvestments': 320013000000,
#   'cashAndShortTermInvestments': 811060000000,
#   'netReceivables': 149054000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 960114000000,
#   'propertyPlantEquipmentNet': 15133000000,
#   'goodwill': 47647000000,
#   'intangibleAssets': 8628000000,
#   'goodwillAndIntangibleAssets': 56275000000,
#   'longTermInvestments': 668017000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -739425000000,
#   'totalNonCurrentAssets': 739425000000,
#   'otherAssets': 873587000000,
#   'totalAssets': 2573126000000,
#   'accountPayables': 206954000000,
#   'shortTermDebt': 66344000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -273298000000,
#   'totalCurrentLiabilities': 273298000000,
#   'longTermDebt': 388757000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -388757000000,
#   'totalNonCurrentLiabilities': 388757000000,
#   'otherLiabilities': 1679006000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2341061000000,
#   'preferredStock': 20063000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 130315000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 2189000000,
#   'othertotalStockholdersEquity': 75393000000,
#   'totalStockholdersEquity': 232065000000,
#   'totalEquity': 232065000000,
#   'totalLiabilitiesAndStockholdersEquity': 2573126000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2573126000000,
#   'totalInvestments': 926457000000,
#   'totalDebt': 455101000000,
#   'netDebt': -57207000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961715000272/corp10k2014.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961715000272/corp10k2014.htm'},
#  {'date': '2013-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2014-02-20',
#   'acceptedDate': '2014-02-19 20:02:20',
#   'calendarYear': '2013',
#   'period': 'FY',
#   'cashAndCashEquivalents': 355822000000,
#   'shortTermInvestments': 308905000000,
#   'cashAndShortTermInvestments': 685799000000,
#   'netReceivables': 130919000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 816718000000,
#   'propertyPlantEquipmentNet': 14891000000,
#   'goodwill': 48081000000,
#   'intangibleAssets': 11232000000,
#   'goodwillAndIntangibleAssets': 59313000000,
#   'longTermInvestments': 662908000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -737112000000,
#   'totalNonCurrentAssets': 737112000000,
#   'otherAssets': 861859000000,
#   'totalAssets': 2415689000000,
#   'accountPayables': 194491000000,
#   'shortTermDebt': 57848000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -252339000000,
#   'totalCurrentLiabilities': 252339000000,
#   'longTermDebt': 376313000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -376313000000,
#   'totalNonCurrentLiabilities': 376313000000,
#   'otherLiabilities': 1575859000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2204511000000,
#   'preferredStock': 11158000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 115756000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 1199000000,
#   'othertotalStockholdersEquity': 78960000000,
#   'totalStockholdersEquity': 211178000000,
#   'totalEquity': 211178000000,
#   'totalLiabilitiesAndStockholdersEquity': 2415689000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2415689000000,
#   'totalInvestments': 952345000000,
#   'totalDebt': 434161000000,
#   'netDebt': 78339000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961714000289/corp10k2013.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961714000289/corp10k2013.htm'},
#  {'date': '2012-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2013-02-28',
#   'acceptedDate': '2013-02-28 16:06:59',
#   'calendarYear': '2012',
#   'period': 'FY',
#   'cashAndCashEquivalents': 175537000000,
#   'shortTermInvestments': 375045000000,
#   'cashAndShortTermInvestments': 546682000000,
#   'netReceivables': 135916000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 114656000000,
#   'propertyPlantEquipmentNet': 14519000000,
#   'goodwill': 48175000000,
#   'intangibleAssets': 9849000000,
#   'goodwillAndIntangibleAssets': 58024000000,
#   'longTermInvestments': 746197000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -753811000000,
#   'totalNonCurrentAssets': 64929000000,
#   'otherAssets': 2179556000000,
#   'totalAssets': 2359141000000,
#   'accountPayables': 195240000000,
#   'shortTermDebt': 55367000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -195240000000,
#   'totalCurrentLiabilities': 55367000000,
#   'longTermDebt': 336922000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1762783000000,
#   'totalNonCurrentLiabilities': 2099705000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2155072000000,
#   'preferredStock': 9058000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 104223000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 4102000000,
#   'othertotalStockholdersEquity': 82581000000,
#   'totalStockholdersEquity': 204069000000,
#   'totalEquity': 204069000000,
#   'totalLiabilitiesAndStockholdersEquity': 2359141000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2359141000000,
#   'totalInvestments': 1083542000000,
#   'totalDebt': 392289000000,
#   'netDebt': 216752000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961713000221/0000019617-13-000221-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961713000221/corp10k2012.htm'},
#  {'date': '2011-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2012-02-29',
#   'acceptedDate': '2012-02-29 10:29:19',
#   'calendarYear': '2011',
#   'period': 'FY',
#   'cashAndCashEquivalents': 144881000000,
#   'shortTermInvestments': 364781000000,
#   'cashAndShortTermInvestments': 509662000000,
#   'netReceivables': 153955000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 121080000000,
#   'propertyPlantEquipmentNet': 14041000000,
#   'goodwill': 48188000000,
#   'intangibleAssets': 10430000000,
#   'goodwillAndIntangibleAssets': 58618000000,
#   'longTermInvestments': 716279000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -723502000000,
#   'totalNonCurrentAssets': 65436000000,
#   'otherAssets': 2079276000000,
#   'totalAssets': 2265792000000,
#   'accountPayables': 202895000000,
#   'shortTermDebt': 51631000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -202895000000,
#   'totalCurrentLiabilities': 51631000000,
#   'longTermDebt': 345401000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1685187000000,
#   'totalNonCurrentLiabilities': 2030588000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2082219000000,
#   'preferredStock': 7800000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 88315000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 944000000,
#   'othertotalStockholdersEquity': 82409000000,
#   'totalStockholdersEquity': 183573000000,
#   'totalEquity': 183573000000,
#   'totalLiabilitiesAndStockholdersEquity': 2265792000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2265792000000,
#   'totalInvestments': 1083682000000,
#   'totalDebt': 397032000000,
#   'netDebt': 252151000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000001961712000163/0000019617-12-000163-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000001961712000163/corp10k2011.htm'},
#  {'date': '2010-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2011-02-28',
#   'acceptedDate': '2011-02-28 16:27:50',
#   'calendarYear': '2010',
#   'period': 'FY',
#   'cashAndCashEquivalents': 49240000000,
#   'shortTermInvestments': 316318000000,
#   'cashAndShortTermInvestments': 365558000000,
#   'netReceivables': 150628000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 516186000000,
#   'propertyPlantEquipmentNet': 13355000000,
#   'goodwill': 48854000000,
#   'intangibleAssets': 17688000000,
#   'goodwillAndIntangibleAssets': 66542000000,
#   'longTermInvestments': 725747000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -805644000000,
#   'totalNonCurrentAssets': 805644000000,
#   'otherAssets': 795775000000,
#   'totalAssets': 2117605000000,
#   'accountPayables': 170330000000,
#   'shortTermDebt': 35363000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -205693000000,
#   'totalCurrentLiabilities': 205693000000,
#   'longTermDebt': 381925000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -381925000000,
#   'totalNonCurrentLiabilities': 381925000000,
#   'otherLiabilities': 1353881000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1941499000000,
#   'preferredStock': 7800000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 73998000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 1001000000,
#   'othertotalStockholdersEquity': 89202000000,
#   'totalStockholdersEquity': 176106000000,
#   'totalEquity': 176106000000,
#   'totalLiabilitiesAndStockholdersEquity': 2117605000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2117605000000,
#   'totalInvestments': 1049492000000,
#   'totalDebt': 417288000000,
#   'netDebt': 368048000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012311019773/y86143e10vk.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012311019773/y86143e10vk.htm'},
#  {'date': '2009-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2010-02-24',
#   'acceptedDate': '2010-02-24 06:19:22',
#   'calendarYear': '2009',
#   'period': 'FY',
#   'cashAndCashEquivalents': 89436000000,
#   'shortTermInvestments': 360365000000,
#   'cashAndShortTermInvestments': 449801000000,
#   'netReceivables': 147637000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 93633000000,
#   'propertyPlantEquipmentNet': 11118000000,
#   'goodwill': 48357000000,
#   'intangibleAssets': 20152000000,
#   'goodwillAndIntangibleAssets': 68509000000,
#   'longTermInvestments': 691308000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -706839000000,
#   'totalNonCurrentAssets': 64096000000,
#   'otherAssets': 1874260000000,
#   'totalAssets': 2031989000000,
#   'accountPayables': 162696000000,
#   'shortTermDebt': 41794000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -162696000000,
#   'totalCurrentLiabilities': 41794000000,
#   'longTermDebt': 387004000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1437826000000,
#   'totalNonCurrentLiabilities': 1824830000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1866624000000,
#   'preferredStock': 8152000000,
#   'commonStock': 4105000000,
#   'retainedEarnings': 62481000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -91000000,
#   'othertotalStockholdersEquity': 90718000000,
#   'totalStockholdersEquity': 165365000000,
#   'totalEquity': 165365000000,
#   'totalLiabilitiesAndStockholdersEquity': 2031989000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 2031989000000,
#   'totalInvestments': 1093570000000,
#   'totalDebt': 428798000000,
#   'netDebt': 339362000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012310016029/0000950123-10-016029-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012310016029/e82150e10vk.htm'},
#  {'date': '2008-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2009-03-02',
#   'acceptedDate': '2009-03-02 16:12:08',
#   'calendarYear': '2008',
#   'period': 'FY',
#   'cashAndCashEquivalents': 165034000000,
#   'shortTermInvestments': 205909000000,
#   'cashAndShortTermInvestments': 370943000000,
#   'netReceivables': 223613000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 87882000000,
#   'propertyPlantEquipmentNet': 10045000000,
#   'goodwill': 48027000000,
#   'intangibleAssets': 14984000000,
#   'goodwillAndIntangibleAssets': 63011000000,
#   'longTermInvestments': 553300000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -564352000000,
#   'totalNonCurrentAssets': 62004000000,
#   'otherAssets': 2035727000000,
#   'totalAssets': 2185613000000,
#   'accountPayables': 187978000000,
#   'shortTermDebt': 37845000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -187978000000,
#   'totalCurrentLiabilities': 37845000000,
#   'longTermDebt': 448357000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 1521966000000,
#   'totalNonCurrentLiabilities': 1970323000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 2008168000000,
#   'preferredStock': 31939000000,
#   'commonStock': 3942000000,
#   'retainedEarnings': 54013000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -5687000000,
#   'othertotalStockholdersEquity': 82677000000,
#   'totalStockholdersEquity': 166884000000,
#   'totalEquity': 177445000000,
#   'totalLiabilitiesAndStockholdersEquity': 2185613000000,
#   'minorityInterest': 10561000000,
#   'totalLiabilitiesAndTotalEquity': 2185613000000,
#   'totalInvestments': 846773000000,
#   'totalDebt': 486202000000,
#   'netDebt': 321168000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012309003840/0000950123-09-003840-index.html',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012309003840/y74757e10vk.htm'},
#  {'date': '2007-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2008-02-29',
#   'acceptedDate': '2008-02-29 15:24:16',
#   'calendarYear': '2007',
#   'period': 'FY',
#   'cashAndCashEquivalents': 51610000000,
#   'shortTermInvestments': 85406000000,
#   'cashAndShortTermInvestments': 137016000000,
#   'netReceivables': 24823000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 161839000000,
#   'propertyPlantEquipmentNet': 9319000000,
#   'goodwill': 45270000000,
#   'intangibleAssets': 14731000000,
#   'goodwillAndIntangibleAssets': 60001000000,
#   'longTermInvestments': 497631000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -566951000000,
#   'totalNonCurrentAssets': 566951000000,
#   'otherAssets': 847373000000,
#   'totalAssets': 1576163000000,
#   'accountPayables': 94476000000,
#   'shortTermDebt': 49596000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -144072000000,
#   'totalCurrentLiabilities': 144072000000,
#   'longTermDebt': 227845000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -227845000000,
#   'totalNonCurrentLiabilities': 227845000000,
#   'otherLiabilities': 1067009000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1438926000000,
#   'preferredStock': 0,
#   'commonStock': 3658000000,
#   'retainedEarnings': 54715000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -917000000,
#   'othertotalStockholdersEquity': 65765000000,
#   'totalStockholdersEquity': 123221000000,
#   'totalEquity': 137237000000,
#   'totalLiabilitiesAndStockholdersEquity': 1576163000000,
#   'minorityInterest': 14016000000,
#   'totalLiabilitiesAndTotalEquity': 1576163000000,
#   'totalInvestments': 583037000000,
#   'totalDebt': 277441000000,
#   'netDebt': 225831000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000119312508043536/d10k.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000119312508043536/d10k.htm'},
#  {'date': '2006-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2007-03-01',
#   'acceptedDate': '2007-03-01 14:41:44',
#   'calendarYear': '2006',
#   'period': 'FY',
#   'cashAndCashEquivalents': 53959000000,
#   'shortTermInvestments': 52346000000,
#   'cashAndShortTermInvestments': 106305000000,
#   'netReceivables': 22891000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 129196000000,
#   'propertyPlantEquipmentNet': 8735000000,
#   'goodwill': 45186000000,
#   'intangibleAssets': 14852000000,
#   'goodwillAndIntangibleAssets': 60038000000,
#   'longTermInvestments': 342027000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -410800000000,
#   'totalNonCurrentAssets': 410800000000,
#   'otherAssets': 827708000000,
#   'totalAssets': 1367704000000,
#   'accountPayables': 88096000000,
#   'shortTermDebt': 18849000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -106945000000,
#   'totalCurrentLiabilities': 106945000000,
#   'longTermDebt': 163683000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -163683000000,
#   'totalNonCurrentLiabilities': 163683000000,
#   'otherLiabilities': 965102000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1235730000000,
#   'preferredStock': 0,
#   'commonStock': 3658000000,
#   'retainedEarnings': 43600000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -1557000000,
#   'othertotalStockholdersEquity': 70089000000,
#   'totalStockholdersEquity': 115790000000,
#   'totalEquity': 131974000000,
#   'totalLiabilitiesAndStockholdersEquity': 1367704000000,
#   'minorityInterest': 16184000000,
#   'totalLiabilitiesAndTotalEquity': 1367704000000,
#   'totalInvestments': 394373000000,
#   'totalDebt': 182532000000,
#   'netDebt': 128573000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012307003015/y30834e10vk.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012307003015/y30834e10vk.htm'},
#  {'date': '2005-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2006-03-09',
#   'acceptedDate': '2006-03-09 17:01:17',
#   'calendarYear': '2005',
#   'period': 'FY',
#   'cashAndCashEquivalents': 58331000000,
#   'shortTermInvestments': 29909000000,
#   'cashAndShortTermInvestments': 58331000000,
#   'netReceivables': 52161000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 110492000000,
#   'propertyPlantEquipmentNet': 9081000000,
#   'goodwill': 43621000000,
#   'intangibleAssets': 14559000000,
#   'goodwillAndIntangibleAssets': 58180000000,
#   'longTermInvestments': 426955000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -494216000000,
#   'totalNonCurrentAssets': 494216000000,
#   'otherAssets': 594234000000,
#   'totalAssets': 1198942000000,
#   'accountPayables': 78460000000,
#   'shortTermDebt': 13863000000,
#   'taxPayables': 0,
#   'deferredRevenue': -64597000000,
#   'otherCurrentLiabilities': -78460000000,
#   'totalCurrentLiabilities': 13863000000,
#   'longTermDebt': 119886000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -119886000000,
#   'totalNonCurrentLiabilities': 119886000000,
#   'otherLiabilities': 915785000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1049534000000,
#   'preferredStock': 139000000,
#   'commonStock': 3618000000,
#   'retainedEarnings': 33848000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -626000000,
#   'othertotalStockholdersEquity': 70232000000,
#   'totalStockholdersEquity': 107211000000,
#   'totalEquity': 149408000000,
#   'totalLiabilitiesAndStockholdersEquity': 1198942000000,
#   'minorityInterest': 42197000000,
#   'totalLiabilitiesAndTotalEquity': 1198942000000,
#   'totalInvestments': 426955000000,
#   'totalDebt': 133749000000,
#   'netDebt': 75418000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012306002875/0000950123-06-002875-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012306002875/y17599e10vk.htm'},
#  {'date': '2004-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2005-03-02',
#   'acceptedDate': '2005-03-02 16:42:32',
#   'calendarYear': '2004',
#   'period': 'FY',
#   'cashAndCashEquivalents': 56848000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 56848000000,
#   'netReceivables': 53131000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 109979000000,
#   'propertyPlantEquipmentNet': 9145000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 57887000000,
#   'longTermInvestments': 438490000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -505522000000,
#   'totalNonCurrentAssets': 505522000000,
#   'otherAssets': 541747000000,
#   'totalAssets': 1157248000000,
#   'accountPayables': 0,
#   'shortTermDebt': 21644000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -21644000000,
#   'totalCurrentLiabilities': 21644000000,
#   'longTermDebt': 105718000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -105718000000,
#   'totalNonCurrentLiabilities': 105718000000,
#   'otherLiabilities': 876172000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 1003534000000,
#   'preferredStock': 339000000,
#   'commonStock': 3585000000,
#   'retainedEarnings': 30209000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -208000000,
#   'othertotalStockholdersEquity': 71728000000,
#   'totalStockholdersEquity': 105653000000,
#   'totalEquity': 153714000000,
#   'totalLiabilitiesAndStockholdersEquity': 1157248000000,
#   'minorityInterest': 48061000000,
#   'totalLiabilitiesAndTotalEquity': 1157248000000,
#   'totalInvestments': 438490000000,
#   'totalDebt': 127362000000,
#   'netDebt': 70514000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012305002539/0000950123-05-002539-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012305002539/y05475e10vk.htm'},
#  {'date': '2003-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2004-02-18',
#   'acceptedDate': '2004-02-18 16:17:06',
#   'calendarYear': '2003',
#   'period': 'FY',
#   'cashAndCashEquivalents': 30443000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 30443000000,
#   'netReceivables': 12356000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 42799000000,
#   'propertyPlantEquipmentNet': 6487000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 14991000000,
#   'longTermInvestments': 362199000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -383677000000,
#   'totalNonCurrentAssets': 383677000000,
#   'otherAssets': 344436000000,
#   'totalAssets': 770912000000,
#   'accountPayables': 0,
#   'shortTermDebt': 23209000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -23209000000,
#   'totalCurrentLiabilities': 23209000000,
#   'longTermDebt': 54782000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -54782000000,
#   'totalNonCurrentLiabilities': 54782000000,
#   'otherLiabilities': 634472000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 712463000000,
#   'preferredStock': 1009000000,
#   'commonStock': 2044000000,
#   'retainedEarnings': 29681000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -30000000,
#   'othertotalStockholdersEquity': 13450000000,
#   'totalStockholdersEquity': 46154000000,
#   'totalEquity': 58449000000,
#   'totalLiabilitiesAndStockholdersEquity': 770912000000,
#   'minorityInterest': 12295000000,
#   'totalLiabilitiesAndTotalEquity': 770912000000,
#   'totalInvestments': 362199000000,
#   'totalDebt': 77991000000,
#   'netDebt': 47548000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012304002022/0000950123-04-002022-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012304002022/y94051e10vk.htm'},
#  {'date': '2002-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2003-03-19',
#   'acceptedDate': '2003-03-19 15:16:01',
#   'calendarYear': '2002',
#   'period': 'FY',
#   'cashAndCashEquivalents': 28160000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 28160000000,
#   'netReceivables': 14137000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 42297000000,
#   'propertyPlantEquipmentNet': 6829000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 12902000000,
#   'longTermInvestments': 375135000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -394866000000,
#   'totalNonCurrentAssets': 394866000000,
#   'otherAssets': 321637000000,
#   'totalAssets': 758800000000,
#   'accountPayables': 0,
#   'shortTermDebt': 25537000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': -25537000000,
#   'totalCurrentLiabilities': 25537000000,
#   'longTermDebt': 45190000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': -45190000000,
#   'totalNonCurrentLiabilities': 45190000000,
#   'otherLiabilities': 645767000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 716494000000,
#   'preferredStock': 1009000000,
#   'commonStock': 2024000000,
#   'retainedEarnings': 25851000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 1227000000,
#   'othertotalStockholdersEquity': 12195000000,
#   'totalStockholdersEquity': 42306000000,
#   'totalEquity': 42306000000,
#   'totalLiabilitiesAndStockholdersEquity': 758800000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 758800000000,
#   'totalInvestments': 375135000000,
#   'totalDebt': 70727000000,
#   'netDebt': 42567000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012303002985/0000950123-03-002985-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012303002985/y83354e10vk.htm'},
#  {'date': '2001-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2002-03-22',
#   'acceptedDate': '2002-03-22 00:00:00',
#   'calendarYear': '2001',
#   'period': 'FY',
#   'cashAndCashEquivalents': 35343000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 35343000000,
#   'netReceivables': 14799000000,
#   'inventory': 0,
#   'otherCurrentAssets': 621794000000,
#   'totalCurrentAssets': 671936000000,
#   'propertyPlantEquipmentNet': 6292000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 15347000000,
#   'longTermInvestments': 294942000000,
#   'taxAssets': -310289000000,
#   'otherNonCurrentAssets': 15347000000,
#   'totalNonCurrentAssets': 21639000000,
#   'otherAssets': 0,
#   'totalAssets': 693575000000,
#   'accountPayables': 0,
#   'shortTermDebt': 29345000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 579509000000,
#   'totalCurrentLiabilities': 608854000000,
#   'longTermDebt': 43622000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 43622000000,
#   'otherLiabilities': -550000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 651926000000,
#   'preferredStock': 1009000000,
#   'commonStock': 1997000000,
#   'retainedEarnings': 26993000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -442000000,
#   'othertotalStockholdersEquity': 11542000000,
#   'totalStockholdersEquity': 41099000000,
#   'totalEquity': 41649000000,
#   'totalLiabilitiesAndStockholdersEquity': 693575000000,
#   'minorityInterest': 550000000,
#   'totalLiabilitiesAndTotalEquity': 693575000000,
#   'totalInvestments': 294942000000,
#   'totalDebt': 72967000000,
#   'netDebt': 37624000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012302002823/0000950123-02-002823-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012302002823/y57010e10-k405.htm'},
#  {'date': '2000-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '2001-03-22',
#   'acceptedDate': '2001-03-22 00:00:00',
#   'calendarYear': '2000',
#   'period': 'FY',
#   'cashAndCashEquivalents': 32305000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 32305000000,
#   'netReceivables': 20618000000,
#   'inventory': 0,
#   'otherCurrentAssets': 639505000000,
#   'totalCurrentAssets': 692428000000,
#   'propertyPlantEquipmentNet': 7087000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 15833000000,
#   'longTermInvestments': 333116000000,
#   'taxAssets': -348949000000,
#   'otherNonCurrentAssets': 15833000000,
#   'totalNonCurrentAssets': 22920000000,
#   'otherAssets': 0,
#   'totalAssets': 715348000000,
#   'accountPayables': 0,
#   'shortTermDebt': 44691000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 581081000000,
#   'totalCurrentLiabilities': 625772000000,
#   'longTermDebt': 47238000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 47238000000,
#   'otherLiabilities': -550000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 672460000000,
#   'preferredStock': 1520000000,
#   'commonStock': 1940000000,
#   'retainedEarnings': 28096000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -241000000,
# ...
#   'totalCurrentAssets': 21949000000,
#   'propertyPlantEquipmentNet': 3780000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 125131000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -128911000000,
#   'totalNonCurrentAssets': 128911000000,
#   'otherAssets': 214661000000,
#   'totalAssets': 365521000000,
#   'accountPayables': 0,
#   'shortTermDebt': 11605000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 317047000000,
#   'totalCurrentLiabilities': 328652000000,
#   'longTermDebt': 15127000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 15127000000,
#   'otherLiabilities': -550000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 343229000000,
#   'preferredStock': 1740000000,
#   'commonStock': 0,
#   'retainedEarnings': 11103000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 95000000,
#   'othertotalStockholdersEquity': 8804000000,
#   'totalStockholdersEquity': 21742000000,
#   'totalEquity': 22292000000,
#   'totalLiabilitiesAndStockholdersEquity': 365521000000,
#   'minorityInterest': 550000000,
#   'totalLiabilitiesAndTotalEquity': 365521000000,
#   'totalInvestments': 125131000000,
#   'totalDebt': 26732000000,
#   'netDebt': 8142000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012398003043/0000950123-98-003043-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012398003043/'},
#  {'date': '1996-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1997-03-25',
#   'acceptedDate': '1997-03-25 00:00:00',
#   'calendarYear': '1996',
#   'period': 'FY',
#   'cashAndCashEquivalents': 22949000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 22949000000,
#   'netReceivables': 3020000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 25969000000,
#   'propertyPlantEquipmentNet': 3642000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 108502000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -112144000000,
#   'totalNonCurrentAssets': 112144000000,
#   'otherAssets': 197986000000,
#   'totalAssets': 336099000000,
#   'accountPayables': 0,
#   'shortTermDebt': 13731000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 288060000000,
#   'totalCurrentLiabilities': 301791000000,
#   'longTermDebt': 13314000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 13314000000,
#   'otherLiabilities': -550000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 314555000000,
#   'preferredStock': 3200000000,
#   'commonStock': 0,
#   'retainedEarnings': 8627000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -288000000,
#   'othertotalStockholdersEquity': 10005000000,
#   'totalStockholdersEquity': 21544000000,
#   'totalEquity': 22094000000,
#   'totalLiabilitiesAndStockholdersEquity': 336099000000,
#   'minorityInterest': 550000000,
#   'totalLiabilitiesAndTotalEquity': 336099000000,
#   'totalInvestments': 108502000000,
#   'totalDebt': 27045000000,
#   'netDebt': 4096000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012397002412/0000950123-97-002412-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/0000950123-97-002412.txt'},
#  {'date': '1995-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1996-03-20',
#   'acceptedDate': '1996-03-20 00:00:00',
#   'calendarYear': '1995',
#   'period': 'FY',
#   'cashAndCashEquivalents': 11743000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 11743000000,
#   'netReceivables': 1328000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 13071000000,
#   'propertyPlantEquipmentNet': 2038000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 70805000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -72843000000,
#   'totalNonCurrentAssets': 72843000000,
#   'otherAssets': 97012000000,
#   'totalAssets': 182926000000,
#   'accountPayables': 0,
#   'shortTermDebt': 9238000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 154447000000,
#   'totalCurrentLiabilities': 163685000000,
#   'longTermDebt': 7329000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 7329000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 171014000000,
#   'preferredStock': 1250000000,
#   'commonStock': 0,
#   'retainedEarnings': 4493000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 6169000000,
#   'totalStockholdersEquity': 11912000000,
#   'totalEquity': 11912000000,
#   'totalLiabilitiesAndStockholdersEquity': 182926000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 182926000000,
#   'totalInvestments': 70805000000,
#   'totalDebt': 16567000000,
#   'netDebt': 4824000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012396001197/0000950123-96-001197-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012396001197/'},
#  {'date': '1994-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1995-03-27',
#   'acceptedDate': '1995-03-27 00:00:00',
#   'calendarYear': '1994',
#   'period': 'FY',
#   'cashAndCashEquivalents': 14481000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 14481000000,
#   'netReceivables': 1190000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 15671000000,
#   'propertyPlantEquipmentNet': 2134000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 55799000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -57933000000,
#   'totalNonCurrentAssets': 57933000000,
#   'otherAssets': 97819000000,
#   'totalAssets': 171423000000,
#   'accountPayables': 0,
#   'shortTermDebt': 11843000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 140877000000,
#   'totalCurrentLiabilities': 152720000000,
#   'longTermDebt': 7991000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 7991000000,
#   'otherLiabilities': 0,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 160711000000,
#   'preferredStock': 1450000000,
#   'commonStock': 0,
#   'retainedEarnings': 3263000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 5999000000,
#   'totalStockholdersEquity': 10712000000,
#   'totalEquity': 10712000000,
#   'totalLiabilitiesAndStockholdersEquity': 171423000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 171423000000,
#   'totalInvestments': 55799000000,
#   'totalDebt': 19834000000,
#   'netDebt': 5353000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012395000706/0000950123-95-000706-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/000095012395000706/'},
#  {'date': '1993-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1994-03-25',
#   'acceptedDate': '1994-03-25 00:00:00',
#   'calendarYear': '1993',
#   'period': 'FY',
#   'cashAndCashEquivalents': 12882000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 12882000000,
#   'netReceivables': 1106000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 13988000000,
#   'propertyPlantEquipmentNet': 1910000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 37627000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -39537000000,
#   'totalNonCurrentAssets': 39537000000,
#   'otherAssets': 96363000000,
#   'totalAssets': 149888000000,
#   'accountPayables': 0,
#   'shortTermDebt': 11908000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 0,
#   'totalCurrentLiabilities': 11908000000,
#   'longTermDebt': 8192000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 8192000000,
#   'otherLiabilities': 118624000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 138724000000,
#   'preferredStock': 1654000000,
#   'commonStock': 0,
#   'retainedEarnings': 2501000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 7009000000,
#   'totalStockholdersEquity': 11164000000,
#   'totalEquity': 11164000000,
#   'totalLiabilitiesAndStockholdersEquity': 149888000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 149888000000,
#   'totalInvestments': 37627000000,
#   'totalDebt': 20100000000,
#   'netDebt': 7218000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/19617/000095012394000607/0000950123-94-000607-index.htm',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/19617/0000950123-94-000607.txt'},
#  {'date': '1992-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1992-12-31',
#   'acceptedDate': '1992-12-30 19:00:00',
#   'calendarYear': '1992',
#   'period': 'FY',
#   'cashAndCashEquivalents': 10692000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 10692000000,
#   'netReceivables': 1086000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 11778000000,
#   'propertyPlantEquipmentNet': 1699000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 27922000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -29621000000,
#   'totalNonCurrentAssets': 29621000000,
#   'otherAssets': 98256000000,
#   'totalAssets': 139655000000,
#   'accountPayables': 0,
#   'shortTermDebt': 8020000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 0,
#   'totalCurrentLiabilities': 8020000000,
#   'longTermDebt': 6798000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 6798000000,
#   'otherLiabilities': 114986000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 129804000000,
#   'preferredStock': 1848000000,
#   'commonStock': 0,
#   'retainedEarnings': 1407000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 6596000000,
#   'totalStockholdersEquity': 9851000000,
#   'totalEquity': 9851000000,
#   'totalLiabilitiesAndStockholdersEquity': 139655000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 139655000000,
#   'totalInvestments': 27922000000,
#   'totalDebt': 14818000000,
#   'netDebt': 4126000000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1991-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1991-12-31',
#   'acceptedDate': '1991-12-30 19:00:00',
#   'calendarYear': '1991',
#   'period': 'FY',
#   'cashAndCashEquivalents': 10616000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 10616000000,
#   'netReceivables': 1187000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 11803000000,
#   'propertyPlantEquipmentNet': 1763000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 26828000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -28591000000,
#   'totalNonCurrentAssets': 28591000000,
#   'otherAssets': 98536000000,
#   'totalAssets': 138930000000,
#   'accountPayables': 0,
#   'shortTermDebt': 9995000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 0,
#   'totalCurrentLiabilities': 9995000000,
#   'longTermDebt': 5738000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 5738000000,
#   'otherLiabilities': 115916000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 131649000000,
#   'preferredStock': 1598000000,
#   'commonStock': 0,
#   'retainedEarnings': 769000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 4914000000,
#   'totalStockholdersEquity': 7281000000,
#   'totalEquity': 7281000000,
#   'totalLiabilitiesAndStockholdersEquity': 138930000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 138930000000,
#   'totalInvestments': 26828000000,
#   'totalDebt': 15733000000,
#   'netDebt': 5117000000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1990-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1990-12-31',
#   'acceptedDate': '1990-12-30 19:00:00',
#   'calendarYear': '1990',
#   'period': 'FY',
#   'cashAndCashEquivalents': 6295000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 6295000000,
#   'netReceivables': 968000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 7263000000,
#   'propertyPlantEquipmentNet': 1007000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 11541000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -12548000000,
#   'totalNonCurrentAssets': 12548000000,
#   'otherAssets': 53208000000,
#   'totalAssets': 73019000000,
#   'accountPayables': 0,
#   'shortTermDebt': 13059000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 0,
#   'totalCurrentLiabilities': 13059000000,
#   'longTermDebt': 3233000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 3233000000,
#   'otherLiabilities': 52820000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 69112000000,
#   'preferredStock': 896000000,
#   'commonStock': 0,
#   'retainedEarnings': 501000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 2510000000,
#   'totalStockholdersEquity': 3907000000,
#   'totalEquity': 3907000000,
#   'totalLiabilitiesAndStockholdersEquity': 73019000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 73019000000,
#   'totalInvestments': 11541000000,
#   'totalDebt': 16292000000,
#   'netDebt': 9997000000,
#   'link': '',
#   'finalLink': ''},
#  {'date': '1989-12-31',
#   'symbol': 'JPM',
#   'reportedCurrency': 'USD',
#   'cik': '0000019617',
#   'fillingDate': '1989-12-31',
#   'acceptedDate': '1989-12-30 19:00:00',
#   'calendarYear': '1989',
#   'period': 'FY',
#   'cashAndCashEquivalents': 6866000000,
#   'shortTermInvestments': 0,
#   'cashAndShortTermInvestments': 6866000000,
#   'netReceivables': 1114000000,
#   'inventory': 0,
#   'otherCurrentAssets': 0,
#   'totalCurrentAssets': 7980000000,
#   'propertyPlantEquipmentNet': 1092000000,
#   'goodwill': 0,
#   'intangibleAssets': 0,
#   'goodwillAndIntangibleAssets': 0,
#   'longTermInvestments': 10227000000,
#   'taxAssets': 0,
#   'otherNonCurrentAssets': -11319000000,
#   'totalNonCurrentAssets': 11319000000,
#   'otherAssets': 52214000000,
#   'totalAssets': 71513000000,
#   'accountPayables': 0,
#   'shortTermDebt': 11225000000,
#   'taxPayables': 0,
#   'deferredRevenue': 0,
#   'otherCurrentLiabilities': 0,
#   'totalCurrentLiabilities': 11225000000,
#   'longTermDebt': 2970000000,
#   'deferredRevenueNonCurrent': 0,
#   'deferredTaxLiabilitiesNonCurrent': 0,
#   'otherNonCurrentLiabilities': 0,
#   'totalNonCurrentLiabilities': 2970000000,
#   'otherLiabilities': 53613000000,
#   'capitalLeaseObligations': 0,
#   'totalLiabilities': 67808000000,
#   'preferredStock': 904000000,
#   'commonStock': 0,
#   'retainedEarnings': 513000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 0,
#   'othertotalStockholdersEquity': 2288000000,
#   'totalStockholdersEquity': 3705000000,
#   'totalEquity': 3705000000,
#   'totalLiabilitiesAndStockholdersEquity': 71513000000,
#   'minorityInterest': 0,
#   'totalLiabilitiesAndTotalEquity': 71513000000,
#   'totalInvestments': 10227000000,
#   'totalDebt': 14195000000,
#   'netDebt': 7329000000,
#   'link': '',
#   'finalLink': ''}]
