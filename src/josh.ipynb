# %%
from finpy_main import FmpClient

from Keys import FMPKey

import pandas as pd
import math

# %%
fmp = FmpClient(FMPKey)

# %%
gs = fmp.get_aggs("WFC")
gs.plot(x='date',y='close')
# Out:
# <Axes: xlabel='date'>

# %%
df = fmp.get_aggs("Voo")
m3 = pd.Timestamp.now() - pd.DateOffset(month=3)
x = df[df['date'].]
x = x[['date','open','close']]
x['range'] = abs(x['close']- x['open'])
# std = x['range'].std()
# normalizing = math.sqrt(20) * std
# normalibzing
# x.to_csv('for_josh.csv')

x = x['date']
# Out:
#   Cell In[35], line 3
#     x = df[df['date'].]
#                       ^
# SyntaxError: invalid syntax

# %%
spy = fmp.get_aggs("SPY")

# %%
spy.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spy.plot()
#
# NameError: name 'spy' is not defined

# %%
spy = spy[spy['date'].dt.year == 2019]
spy = spy[spy['date'].dt.month >= 1]
spy = spy[spy['date'].dt.month < 4]
spy = spy[['date','open','close']]
spy['range'] = abs(spy['close']- spy['open'])
std = spy['range'].std()
norm_mon = math.sqrt(20) * std
norm_mon *2
# # spy
# Out:
# 10.781321431219794

# %%
m3
# Out:
# Timestamp('2024-03-01 10:31:14.795740')

# %%
spy = fmp.get_aggs("SPY")

# %%
spy_filt = df[df['date']dt.date <= '2019-06-01' & df['date'].dt.date >= '2019-03-01']]
spy_filt
# Out:
#   Cell In[13], line 1
#     spy_filt = df[df['date']dt.date <= '2019-06-01' & df['date'].dt.date >= '2019-03-01']]
#                                                                                          ^
# SyntaxError: unmatched ']'
